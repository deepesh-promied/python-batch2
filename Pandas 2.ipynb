# %%
import pandas as pd

# %%
df = pd.read_csv('Data/File1.csv',names=['Name','Gender','Subject','Marks']) # Passing Column names as names variable in list

# %%
df
# Out:
#           Name  Gender    Subject  Marks
# 0        Aamir    Male    Physics     97
# 1        Aamir    Male    Science     42
# 2      Abagael  Female  Economics     49
# 3      Abagail  Female  Chemistry     39
# 4         Abbe  Female    Physics     38
# ...        ...     ...        ...    ...
# 1995  Dimitris    Male    Physics     43
# 1996  Dimitrou    Male  Chemistry     77
# 1997   Dimitry    Male      Maths     22
# 1998      Dina  Female    Science     52
# 1999     Dinah  Female    Physics     65
#
# [2000 rows x 4 columns]

# %%
df[df['Name']=='Aamir']
# Out:
#     Name Gender  Subject  Marks
# 0  Aamir   Male  Physics     97
# 1  Aamir   Male  Science     42

# %%
df.iloc[1999] #Accing using Index
# Out:
# Name         Dinah
# Gender      Female
# Subject    Physics
# Marks           65
# Name: 1999, dtype: object

# %%
df.iloc[[1,1999]]
# Out:
#        Name  Gender  Subject  Marks
# 1     Aamir    Male  Science     42
# 1999  Dinah  Female  Physics     65

# %%
df.iloc[1:] #Prints from starting index till end
# Out:
#           Name  Gender    Subject  Marks
# 1        Aamir    Male    Science     42
# 2      Abagael  Female  Economics     49
# 3      Abagail  Female  Chemistry     39
# 4         Abbe  Female    Physics     38
# 5        Abbey    Male      Maths     61
# ...        ...     ...        ...    ...
# 1995  Dimitris    Male    Physics     43
# 1996  Dimitrou    Male  Chemistry     77
# 1997   Dimitry    Male      Maths     22
# 1998      Dina  Female    Science     52
# 1999     Dinah  Female    Physics     65
#
# [1999 rows x 4 columns]

# %%
df.iloc[500::-25]
# Out:
#             Name  Gender    Subject  Marks
# 500        Arden  Female      Maths     52
# 475    Aphrodite  Female  Economics     89
# 450        Anson    Male    History     67
# 425  Annecorinne  Female    Science     80
# 400    Anjanette  Female  Economics     44
# 375        Angel    Male  Economics     90
# 350     Andreana  Female    History     48
# 325     Anabella  Female  Economics     24
# 300        Amber  Female    Science     36
# 275        Alyda  Female  Economics     62
# 250       Almeda  Female    Science     29
# 225         Alla  Female    Physics     89
# 200      Alfreda  Female    History     99
# 175   Alessandra  Female    Physics     82
# 150    Albertine  Female    Science     20
# 125         Aina  Female    Physics     22
# 100       Agneta  Female    Science     95
# 75       Adriane  Female    History     77
# 50         Adena  Female      Maths     60
# 25          Abra  Female  Economics     61
# 0          Aamir    Male    Physics     97

# %%
df.iloc[1:100]
# Out:
#        Name  Gender    Subject  Marks
# 1     Aamir    Male    Science     42
# 2   Abagael  Female  Economics     49
# 3   Abagail  Female  Chemistry     39
# 4      Abbe  Female    Physics     38
# 5     Abbey    Male      Maths     61
# ..      ...     ...        ...    ...
# 95     Agna  Female      Maths     61
# 96  Agnella  Female    Physics     26
# 97    Agnes  Female    Science     66
# 98   Agnese  Female    Physics     94
# 99  Agnesse  Female    History     79
#
# [99 rows x 4 columns]

# %%
df.iloc[1:1000:25]
# Out:
#              Name  Gender    Subject  Marks
# 1           Aamir    Male    Science     42
# 26        Abraham    Male    Physics     81
# 51           Adey  Female    History     81
# 76       Adrianna  Female  Chemistry     50
# 101        Agnola  Female    Physics     86
# 126       Aindrea  Female  Chemistry     27
# 151       Alberto    Male    History     28
# 176    Alessandro    Male  Economics     52
# 201       Alfredo    Male    History     81
# 226         Allah    Male    History     63
# 251       Almeria  Female    Physics     32
# 276          Alys  Female    Science     39
# 301       Amberly  Female    Physics     32
# 326      Anabelle  Female    Physics     20
# 351       Andreas    Male    Science     30
# 376         Angel  Female  Chemistry     42
# 401        Anjela  Female    Physics     34
# 426  Anne-Corinne  Female    History     68
# 451       Anstice  Female    Physics     73
# 476        Apollo    Male    History     59
# ...

# %%
df.iloc[[1,2,3],[0,1]] #Indexing Rows and Columns
# Out:
#       Name  Gender
# 1    Aamir    Male
# 2  Abagael  Female
# 3  Abagail  Female

# %%
df.iloc[1:200,2:]
# Out:
#        Subject  Marks
# 1      Science     42
# 2    Economics     49
# 3    Chemistry     39
# 4      Physics     38
# 5        Maths     61
# ..         ...    ...
# 195  Economics     40
# 196  Economics     98
# 197    History     28
# 198    Physics     42
# 199    Science     85
#
# [199 rows x 2 columns]

# %%
df.iloc[[1,2,3],['Name','Marks']] #Gives Error if non numeric column names are entered
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-69200c6ec11f> in <module>
# ----> 1 df.iloc[[1,2,3],['Name','Marks']]
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2065     def _getitem_tuple(self, tup: Tuple):
#    2066
# -> 2067         self._has_valid_tuple(tup)
#    2068         try:
#    2069             return self._getitem_lowerdim(tup)
#
# ...

# %% [markdown]
# # loc Method

# %%
df.loc[1:,['Name','Gender']]
# Out:
#           Name  Gender
# 1        Aamir    Male
# 2      Abagael  Female
# 3      Abagail  Female
# 4         Abbe  Female
# 5        Abbey    Male
# ...        ...     ...
# 1995  Dimitris    Male
# 1996  Dimitrou    Male
# 1997   Dimitry    Male
# 1998      Dina  Female
# 1999     Dinah  Female
#
# [1999 rows x 2 columns]

# %%
df2 = pd.read_csv('Data/File2.csv',names=['Name','Gender','Marks'])

# %%
df2
# Out:
#           Name  Gender  Marks
# 0       Dinnie  Female     90
# 1        Dinny  Female     46
# 2         Dino    Male     51
# 3         Dion    Male     66
# 4         Dion  Female     51
# ...        ...     ...    ...
# 1995    Kaiser    Male     50
# 1996   Kaitlin  Female     50
# 1997   Kaitlyn  Female     49
# 1998  Kaitlynn  Female     99
# 1999      Kaja  Female     24
#
# [2000 rows x 3 columns]

# %%
df
# Out:
#           Name  Gender    Subject  Marks
# 0        Aamir    Male    Physics     97
# 1        Aamir    Male    Science     42
# 2      Abagael  Female  Economics     49
# 3      Abagail  Female  Chemistry     39
# 4         Abbe  Female    Physics     38
# ...        ...     ...        ...    ...
# 1995  Dimitris    Male    Physics     43
# 1996  Dimitrou    Male  Chemistry     77
# 1997   Dimitry    Male      Maths     22
# 1998      Dina  Female    Science     52
# 1999     Dinah  Female    Physics     65
#
# [2000 rows x 4 columns]

# %%
df3 = pd.concat([df,df2],ignore_index=True)

# %%
df3
# Out:
#           Name  Gender    Subject  Marks
# 0        Aamir    Male    Physics     97
# 1        Aamir    Male    Science     42
# 2      Abagael  Female  Economics     49
# 3      Abagail  Female  Chemistry     39
# 4         Abbe  Female    Physics     38
# ...        ...     ...        ...    ...
# 3995    Kaiser    Male        NaN     50
# 3996   Kaitlin  Female        NaN     50
# 3997   Kaitlyn  Female        NaN     49
# 3998  Kaitlynn  Female        NaN     99
# 3999      Kaja  Female        NaN     24
#
# [4000 rows x 4 columns]

# %%
df3.iloc[0] #iloc is uses the position
# Out:
# Name         Aamir
# Gender        Male
# Subject    Physics
# Marks           97
# Name: 0, dtype: object

# %%
df3.loc[[0],['Name','Gender','Subject']] #loc using index values
# Out:
#     Name Gender  Subject
# 0  Aamir   Male  Physics

# %%
df.to_csv('Data/FinalFile.csv')
